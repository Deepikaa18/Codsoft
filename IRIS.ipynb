# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepikaa18/Codsoft/blob/main/IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print( "               ******          DATASET FOR IRIS          *******")
print("                ")
print("                ")
import pandas as pd
a = pd.read_csv("IRIS.csv")
print(a)
# Out:
#                ******          DATASET FOR IRIS          *******
#
#
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# ...

# %%
a.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
print("                                   *-*   PREPROCESSING   *-*                        ")
print("            ")
from sklearn import preprocessing
d = preprocessing.LabelEncoder()
a["species"] = d.fit_transform(a["species"])
a["species"].unique
# Out:
#                                    *-*   PREPROCESSING   *-*
# <bound method Series.unique of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64>

# %%
print("                 *  PLOT  *             ")
print("              ")
from matplotlib import pyplot as plt
plt.plot(a["sepal_length"],a["petal_width"])
# Out:
#                  *  PLOT  *

# %%
print("                            ^  BAR  ^                      ")
print("                  ")
from matplotlib import pyplot as plt
plt.bar(a["sepal_length"],a["petal_width"])
# Out:
#                             ^  BAR  ^
# <BarContainer object of 150 artists>

# %%
print("                                    *  SCATTER  *                  ")
print("                    ")
from matplotlib import pyplot as plt
plt.scatter(a["petal_width"],a["sepal_length"])
# Out:
#                                     *  SCATTER  *

# %%
print("                              ^  Histogram  ^             ")
print("                ")
from matplotlib import pyplot as plt
plt.hist(a["petal_width"])
# Out:
#                               ^  Histogram  ^
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
print("                         *  LMPLOT  *         ")
print("                       ")
import seaborn as sd
sd.lmplot(x="sepal_length",y="petal_width",data=a)
# Out:
#                          *  LMPLOT  *

# %%
print("                              ^  BARPLOT  ^        ")
print("                         ")
import seaborn as sd
sd.barplot(x="sepal_length",y="petal_width",data=a)
# Out:
#                               ^  BARPLOT  ^
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
print("                               *  BOXPLOT  *            ")
print("            ")
import seaborn as sd
sd.boxplot(x="sepal_length",y="petal_width",data=a)
# Out:
#                                *  BOXPLOT  *
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
print("                    *  DISTPLOT  *")
print("          ")
sd.distplot(a.sepal_length)
# Out:
#                     *  DISTPLOT  *
# <ipython-input-34-22589244f77b>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sd.distplot(a.sepal_length)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
print("                      *  X Values  * ")
print("        ")
x = a.sepal_length
print(x)
# Out:
#                       *  X Values  *
#
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
print("             *  Y Values  *")
print("   ")
y = a["petal_length"]
print(y)
# Out:
#              *  Y Values  *
#
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
print("                             *  X Train   and    X Test   *         ")
print("            ")
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size=0.20,shuffle=True)
print(x_train)
print(x_test)
# Out:
#                              *  X Train   and    X Test   *
#
# 4      5.0
# 56     6.3
# 118    7.7
# 14     5.8
# 90     5.5
#       ...
# 28     5.2
# 81     5.5
# 36     5.5
# 31     5.4
# 105    7.6
# Name: sepal_length, Length: 120, dtype: float64
# 133    6.3
# 98     5.1
# 13     4.3
# 84     5.4
# 126    6.2
# 116    6.5
# 128    6.4
# 53     5.5
# 30     4.8
# 125    7.2
# 38     4.4
# 59     5.2
# 73     6.1
# 12     4.8
# 15     5.7
# 67     5.8
# 43     5.0
# 89     5.5
# 10     5.4
# 100    6.3
# 51     6.4
# 11     4.8
# 96     5.7
# 144    6.7
# 86     6.7
# 32     5.2
# 45     4.8
# 17     5.1
# 0      5.1
# 75     6.6
# Name: sepal_length, dtype: float64

# %%
print("               *  Y Train   and   Y Test   *   ")
print("       ")
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,shuffle=True)
print(y_train)
print(y_test)
# Out:
#                *  Y Train   and   Y Test   *
#
# 29     1.6
# 20     1.7
# 132    5.6
# 41     1.3
# 43     1.6
#       ...
# 87     4.4
# 76     4.8
# 6      1.4
# 45     1.4
# 58     4.6
# Name: petal_length, Length: 120, dtype: float64
# 3      1.5
# 147    5.2
# 74     4.3
# 106    4.5
# 149    5.1
# 44     1.9
# 38     1.3
# 1      1.4
# 112    5.5
# 114    5.1
# 73     4.7
# 118    6.9
# 121    4.9
# 32     1.5
# 133    5.1
# 125    6.0
# 69     3.9
# 107    6.3
# 131    6.4
# 72     4.9
# 53     4.0
# 59     3.9
# 98     3.0
# 40     1.3
# 128    5.6
# 65     4.4
# 96     4.2
# 55     4.5
# 94     4.2
# 35     1.2
# Name: petal_length, dtype: float64
