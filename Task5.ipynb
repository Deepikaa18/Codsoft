# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepikaa18/Codsoft/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
a = pd.read_csv("creditcard.csv")
print(a)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 73372  55105  1.104021 -1.123835  1.008939 -0.460960 -1.502758  0.021138
# 73373  55105  1.182898 -0.283273  1.123494  0.066948 -1.283276 -0.900451
# 73374  55106  1.168124 -0.122507  1.251822  0.860341 -1.020137 -0.277310
# 73375  55106 -0.339385 -2.095670  0.271543 -3.066469  0.484794  3.870704
# 73376  55107 -1.020407  0.160171  0.152264 -0.093406 -0.978017  0.074549
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
a.isna()
# Out:
#         Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73372  False  False  False  False  False  False  False  False  False  False
# 73373  False  False  False  False  False  False  False  False  False  False
# 73374  False  False  False  False  False  False  False  False  False  False
# 73375  False  False  False  False  False  False  False  False  False  False
# 73376  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
#  **Visulaization**

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,10)
plt.plot(a)

# %%
import seaborn as sd
sd.barplot(x="Age",y="Name",data=a)
# Out:
# <Axes: xlabel='Age', ylabel='Name'>

# %%
sd.distplot(a.Amount)
# Out:
# <ipython-input-95-13a6c4c0904a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sd.distplot(a.Amount)
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
x = a["Time"]
print(x)
# Out:
# 0          0
# 1          0
# 2          1
# 3          1
# 4          2
#         ...
# 1981    1524
# 1982    1525
# 1983    1525
# 1984    1525
# 1985    1526
# Name: Time, Length: 1986, dtype: int64

# %%
y = a["V1"]
print(y)
# Out:
# 0      -1.359807
# 1       1.191857
# 2      -1.358354
# 3      -0.966272
# 4      -1.158233
#           ...
# 1981   -0.340622
# 1982   -1.842696
# 1983   -0.480693
# 1984   -0.342132
# 1985   -0.854343
# Name: V1, Length: 1986, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size=0.20,shuffle=True)
print(x_train)
print(x_test)
# Out:
# 318    0
# 47     0
# 195    0
# 133    1
# 3      0
#       ..
# 69     1
# 281    1
# 249    1
# 339    0
# 211    0
# Name: SibSp, Length: 334, dtype: int64
# 330    0
# 186    0
# 340    0
# 224    0
# 112    0
#       ..
# 177    1
# 142    1
# 349    0
# 390    0
# 215    0
# Name: SibSp, Length: 84, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,shuffle=True)
print(y_train)
print(y_test)
# Out:
# 86     1
# 37     1
# 326    1
# 65     1
# 41     0
#       ..
# 319    0
# 102    0
# 198    0
# 230    0
# 153    1
# Name: Survived, Length: 334, dtype: int64
# 81     0
# 293    0
# 90     1
# 343    1
# 123    0
#       ..
# 227    1
# 397    1
# 132    1
# 56     0
# 85     0
# Name: Survived, Length: 84, dtype: int64
